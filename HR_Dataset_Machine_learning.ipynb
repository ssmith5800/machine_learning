# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Datasets/HRData_set.csv')

# %%
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
df.dtypes
# Out:
# Employee_Name                  object
# EmpID                           int64
# MarriedID                       int64
# MaritalStatusID                 int64
# GenderID                        int64
# EmpStatusID                     int64
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID          int64
# Salary                          int64
# Termd                           int64
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %%
df.count()
# Out:
# Employee_Name                 311
# EmpID                         311
# MarriedID                     311
# MaritalStatusID               311
# GenderID                      311
# EmpStatusID                   311
# DeptID                        311
# PerfScoreID                   311
# FromDiversityJobFairID        311
# Salary                        311
# Termd                         311
# PositionID                    311
# Position                      311
# State                         311
# Zip                           311
# DOB                           311
# Sex                           311
# MaritalDesc                   311
# CitizenDesc                   311
# HispanicLatino                311
# RaceDesc                      311
# DateofHire                    311
# DateofTermination             104
# TermReason                    311
# EmploymentStatus              311
# Department                    311
# ManagerName                   311
# ...

# %%
df1 = df.dropna()
df1.count()
# Out:
# Employee_Name                 104
# EmpID                         104
# MarriedID                     104
# MaritalStatusID               104
# GenderID                      104
# EmpStatusID                   104
# DeptID                        104
# PerfScoreID                   104
# FromDiversityJobFairID        104
# Salary                        104
# Termd                         104
# PositionID                    104
# Position                      104
# State                         104
# Zip                           104
# DOB                           104
# Sex                           104
# MaritalDesc                   104
# CitizenDesc                   104
# HispanicLatino                104
# RaceDesc                      104
# DateofHire                    104
# DateofTermination             104
# TermReason                    104
# EmploymentStatus              104
# Department                    104
# ManagerName                   104
# ...

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
# Using .rename(columns={}) in order to rename columns
renamed_df = df.rename(columns={'Employee_Name':'Employee Name', 'EmpID':'Employee ID', 'EmpStatusID':'Employee Status', 'DeptID':'Department ID',
       'DateofHire':'Date of Hire', 'DateofTermination':'Date of Termination', 'TermReason':'Reason for Termination', 'EmploymentStatus':'Employment Status', 'ManagerName':'Manager Name',
       'PerformanceScore':'Performance Score', 'EmpSatisfaction':'Employee Satisfaction',
       'SpecialProjectsCount':'Special Project Count', 'LastPerformanceReview_Date':'Last Performance Review Date', 'DaysLateLast30':'Days Late Last 30 Days'})
renamed_df.head()
# Out:
#               Employee Name  Employee ID  MarriedID  MaritalStatusID  \
# 0       Adinolfi, Wilson  K        10026          0                0
# 1  Ait Sidi, Karthikeyan           10084          1                1
# 2         Akinkuolie, Sarah        10196          1                1
# 3              Alagbe,Trina        10088          1                1
# 4          Anderson, Carol         10069          0                2
#
#    GenderID  Employee Status  Department ID  PerfScoreID  \
# 0         1                1              5            4
# 1         1                5              3            3
# 2         0                5              5            3
# 3         0                1              5            3
# 4         0                5              5            3
#
#    FromDiversityJobFairID  Salary  ...    Manager Name  ManagerID  \
# 0                       0   62506  ...  Michael Albert       22.0
# 1                       0  104437  ...      Simon Roup        4.0
# ...
